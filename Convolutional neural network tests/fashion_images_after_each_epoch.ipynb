# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images / 255.0
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images / 255.0


# Define the CNN architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), name='conv2d_1'),
    tf.keras.layers.MaxPooling2D((2, 2), name='max_pooling2d_1'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', name='conv2d_2'),
    tf.keras.layers.MaxPooling2D((2, 2), name='max_pooling2d_2'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', name='conv2d_3'),
    tf.keras.layers.Flatten(name='flatten'),
    tf.keras.layers.Dense(128, activation='relu', name='dense_1'),
    tf.keras.layers.Dense(10, activation='softmax', name='output')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model and display the activations after each 3 epochs

epochs = 15
for epoch in range(1, epochs+1):
    history = model.fit(train_images, train_labels, epochs=1, validation_data=(test_images, test_labels))
    if epoch % 3 == 0:
        # Get the layer outputs and names
        layer_names = ['conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'conv2d_3']
        layer_outputs = [layer.output for layer in model.layers if layer.name in layer_names]
        activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)

        # Get the activation outputs for the test images
        activations = activation_model.predict(test_images)

        # Display the activation outputs of the convolutional layers as images on a grid
        for layer_name, layer_activation in zip(layer_names, activations):
            n_features = layer_activation.shape[-1]
            size = layer_activation.shape[1]
            n_cols = n_features // 8
            display_grid = np.zeros((size * n_cols, 8 * size))
            for col in range(n_cols):
                for row in range(8):
                    channel_image = layer_activation[0, :, :, col * 8 + row]
                    channel_image -= channel_image.mean()
                    channel_image /= channel_image.std()
                    channel_image *= 64
                    channel_image += 128
                    channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                    display_grid[col * size:(col + 1) * size, row * size:(row + 1) * size] = channel_image
            scale = 1. / size
            plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
            plt.title(layer_name)
            plt.grid(False)
            plt.imshow(display_grid, aspect= 'auto',cmap='gray')    
        plt.show()
# Out:
# /Users/gedena/miniconda3/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-02 21:13:30.022054: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-02 21:13:30.022882: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-03-02 21:13:30.412802: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-02 21:13:30.612733: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.8253
# 2023-03-02 21:13:46.344267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.4753 - accuracy: 0.8253 - val_loss: 0.3665 - val_accuracy: 0.8685
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3084 - accuracy: 0.8870 - val_loss: 0.3061 - val_accuracy: 0.8873
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2609 - accuracy: 0.9036 - val_loss: 0.2894 - val_accuracy: 0.8924
#  82/313 [======>.......................] - ETA: 0s
# 2023-03-02 21:14:20.331780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# /var/folders/1t/sj3jytd91z53kgnkw3mqp59r0000gn/T/ipykernel_17442/1469197420.py:55: RuntimeWarning: invalid value encountered in divide
#   channel_image /= channel_image.std()
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2283 - accuracy: 0.9148 - val_loss: 0.2734 - val_accuracy: 0.9007
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2022 - accuracy: 0.9241 - val_loss: 0.2571 - val_accuracy: 0.9061
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1802 - accuracy: 0.9328 - val_loss: 0.2651 - val_accuracy: 0.9069
#  84/313 [=======>......................] - ETA: 0s
# 2023-03-02 21:15:13.078708: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1591 - accuracy: 0.9398 - val_loss: 0.2643 - val_accuracy: 0.9103
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1434 - accuracy: 0.9456 - val_loss: 0.2786 - val_accuracy: 0.9076
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1272 - accuracy: 0.9519 - val_loss: 0.2852 - val_accuracy: 0.9110
#  86/313 [=======>......................] - ETA: 0s
# 2023-03-02 21:16:05.235150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1133 - accuracy: 0.9571 - val_loss: 0.2922 - val_accuracy: 0.9103
# 1597/1875 [========================>.....] - ETA: 2s - loss: 0.1031 - accuracy: 0.9595
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 35
#      33 epochs = 15
#      34 for epoch in range(1, epochs+1):
# ---> 35     history = model.fit(train_images, train_labels, epochs=1, validation_data=(test_images, test_labels))
#      36     if epoch % 3 == 0:
#      37         # Get the layer outputs and names
#      38         layer_names = ['conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'conv2d_3']
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2452, in Function.__call__(self, *args, **kwargs)
#    2449 """Calls a graph function specialized to the inputs."""
#    2450 with self._lock:
#    2451   (graph_function,
# -> 2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2689, in Function._maybe_define_function(self, args, kwargs)
#    2684 except TypeError as e:
#    2685   raise TypeError(
#    2686       "Arguments supplied to `defun`-generated functions must be "
#    2687       f"hashable.  Original error: {e}.")
# -> 2689 graph_function = self._function_cache.lookup(cache_key, True)
#    2690 if graph_function is not None:
#    2691   return graph_function, filtered_flat_args
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:119, in FunctionCache.lookup(self, key, use_function_subtyping)
#     116 if not use_function_subtyping:
#     117   return self._primary.get(key, None)
# --> 119 dispatch_key = self._dispatch_table.dispatch(key)
#     120 if dispatch_key is not None:
#     121   return self._primary[dispatch_key]
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/type_dispatch.py:78, in TypeDispatchTable.dispatch(self, request)
#      76 """Returns the deepest subtype target if it exists in the table."""
#      77 # For known exact matches.
# ---> 78 if request in self._dispatch_table:
#      79   return request
#      81 # For known non-exact matches.
#      82 # (self._dispatch cache does not contain exact matches)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:79, in FunctionCacheKey.__eq__(self, other)
#      78 def __eq__(self, other) -> bool:
# ---> 79   if not isinstance(other, trace.TraceType):
#      80     return NotImplemented
#      82   if not isinstance(other, FunctionCacheKey):
#
# File ~/miniconda3/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
