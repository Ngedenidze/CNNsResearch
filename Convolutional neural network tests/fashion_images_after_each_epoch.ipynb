# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images / 255.0
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images / 255.0


# Define the CNN architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), name='conv2d_1'),
    tf.keras.layers.MaxPooling2D((2, 2), name='max_pooling2d_1'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', name='conv2d_2'),
    tf.keras.layers.MaxPooling2D((2, 2), name='max_pooling2d_2'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', name='conv2d_3'),
    tf.keras.layers.Flatten(name='flatten'),
    tf.keras.layers.Dense(128, activation='relu', name='dense_1'),
    tf.keras.layers.Dense(10, activation='softmax', name='output')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model and display the activations after each 3 epochs

epochs = 15
for epoch in range(1, epochs+1):
    history = model.fit(train_images, train_labels, epochs=1, validation_data=(test_images, test_labels))
    if epoch % 3 == 0:
        # Get the layer outputs and names
        layer_names = ['conv2d_1', 'max_pooling2d_1', 'conv2d_2', 'max_pooling2d_2', 'conv2d_3']
        layer_outputs = [layer.output for layer in model.layers if layer.name in layer_names]
        activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)

        # Get the activation outputs for the test images
        activations = activation_model.predict(test_images)

        # Display the activation outputs of the convolutional layers as images on a grid
        for layer_name, layer_activation in zip(layer_names, activations):
            n_features = layer_activation.shape[-1]
            size = layer_activation.shape[1]
            n_cols = n_features // 8
            display_grid = np.zeros((size * n_cols, 8 * size))
            for col in range(n_cols):
                for row in range(8):
                    channel_image = layer_activation[0, :, :, col * 8 + row]
                    channel_image -= channel_image.mean()
                    channel_image /= channel_image.std()
                    channel_image *= 64
                    channel_image += 128
                    channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                    display_grid[col * size:(col + 1) * size, row * size:(row + 1) * size] = channel_image
            scale = 1. / size
            plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
            plt.title(layer_name)
            plt.grid(False)
            plt.imshow(display_grid, aspect= 'auto',cmap='gray')    
        plt.show()
# Out:
# /Users/gedena/miniconda3/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-02-24 15:33:18.047138: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-24 15:33:18.050556: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-02-24 15:33:18.487620: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#    1/1875 [..............................] - ETA: 11:17 - loss: 2.3053 - accuracy: 0.0312
# 2023-02-24 15:33:18.693570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.4687 - accuracy: 0.8286
# 2023-02-24 15:33:33.861239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.4685 - accuracy: 0.8287 - val_loss: 0.3369 - val_accuracy: 0.8761
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3051 - accuracy: 0.8874 - val_loss: 0.3041 - val_accuracy: 0.8886
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2629 - accuracy: 0.9031 - val_loss: 0.2902 - val_accuracy: 0.8939
#  87/313 [=======>......................] - ETA: 0s
# 2023-02-24 15:34:07.751262: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# /var/folders/1t/sj3jytd91z53kgnkw3mqp59r0000gn/T/ipykernel_913/1469197420.py:55: RuntimeWarning: invalid value encountered in divide
#   channel_image /= channel_image.std()
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2286 - accuracy: 0.9143 - val_loss: 0.2800 - val_accuracy: 0.8982
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2028 - accuracy: 0.9243 - val_loss: 0.2570 - val_accuracy: 0.9061
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1800 - accuracy: 0.9324 - val_loss: 0.2682 - val_accuracy: 0.9113
#  89/313 [=======>......................] - ETA: 0s
# 2023-02-24 15:35:01.706204: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1603 - accuracy: 0.9399 - val_loss: 0.2904 - val_accuracy: 0.9060
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1437 - accuracy: 0.9449 - val_loss: 0.2619 - val_accuracy: 0.9118
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1270 - accuracy: 0.9521 - val_loss: 0.2932 - val_accuracy: 0.9091
#  73/313 [=====>........................] - ETA: 0s
# 2023-02-24 15:35:53.530177: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1150 - accuracy: 0.9567 - val_loss: 0.3085 - val_accuracy: 0.9135
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1035 - accuracy: 0.9599 - val_loss: 0.3002 - val_accuracy: 0.9095
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0918 - accuracy: 0.9647 - val_loss: 0.3267 - val_accuracy: 0.9126
#  39/313 [==>...........................] - ETA: 0s
# 2023-02-24 15:36:47.955099: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 3ms/step
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0856 - accuracy: 0.9674 - val_loss: 0.3644 - val_accuracy: 0.9096
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0776 - accuracy: 0.9704 - val_loss: 0.3567 - val_accuracy: 0.9110
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0694 - accuracy: 0.9739 - val_loss: 0.3900 - val_accuracy: 0.9086
#  71/313 [=====>........................] - ETA: 0s
# 2023-02-24 15:37:43.540608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
