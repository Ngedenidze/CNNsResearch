# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf 

mnist = tf.keras.datasets.mnist

# loading data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# scaling down, normilizing
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# creating model for nural networlk
model = tf.keras.models.Sequential()


# adding layers to nueral network

# flatten layer
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
# dense layer
model.add(tf.keras.layers.Dense(128, activation='relu'))
# dense layer
model.add(tf.keras.layers.Dense(128, activation='relu'))
# dense layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))


# compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# fit/train the model
model.fit(x_train, y_train, epochs=3)

model.save('handwritten.model')
# Out:
# Metal device set to: Apple M2
# 2023-02-14 23:06:02.169072: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-14 23:06:02.171215: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/3
# 2023-02-14 23:06:02.479900: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-14 23:06:02.732590: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-14 23:06:02.812788: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# 2023-02-14 23:06:02.812812: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# 2023-02-14 23:06:02.820096: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# 2023-02-14 23:06:02.820113: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# 2023-02-14 23:06:03.015362: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# 2023-02-14 23:06:03.015383: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:418 : NOT_FOUND: could not find registered platform with id: 0x1599b7a50
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[1], line 36
#      33 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      35 # fit/train the model
# ---> 36 model.fit(x_train, y_train, epochs=3)
#      38 model.save('handwritten.model')
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node 'StatefulPartitionedCall_4' defined at (most recent call last):
#     File "/Users/gedena/miniconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/gedena/miniconda3/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/gedena/miniconda3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/Users/gedena/miniconda3/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#       handle._run()
#     File "/Users/gedena/miniconda3/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#       result = self._run_cell(
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#       return runner(coro)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/1t/sj3jytd91z53kgnkw3mqp59r0000gn/T/ipykernel_49624/4078121232.py", line 36, in <module>
#       model.fit(x_train, y_train, epochs=3)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 527, in minimize
#       self.apply_gradients(grads_and_vars)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1140, in apply_gradients
#       return super().apply_gradients(grads_and_vars, name=name)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 634, in apply_gradients
#       iteration = self._internal_apply_gradients(grads_and_vars)
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1166, in _internal_apply_gradients
#       return tf.__internal__.distribute.interim.maybe_merge_call(
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1216, in _distributed_apply_gradients_fn
#       distribution.extended.update(
#     File "/Users/gedena/miniconda3/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1211, in apply_grad_to_update_var
#       return self._update_step_xla(grad, var, id(self._var_key(var)))
# Node: 'StatefulPartitionedCall_4'
# could not find registered platform with id: 0x1599b7a50
# 	 [[{{node StatefulPartitionedCall_4}}]] [Op:__inference_train_function_906]

# %%
# !pip install tensorflow-macos==2.9 tensorflow-metal==0.5.0 tensorflow-gpu opencv-python matplotlib
# Out:
# Collecting tensorflow-macos==2.9
#   Downloading tensorflow_macos-2.9.0-cp310-cp310-macosx_11_0_arm64.whl (200.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 MB 10.7 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-metal==0.5.0
#   Downloading tensorflow_metal-0.5.0-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.0 MB/s eta 0:00:00a 0:00:01
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.68-cp37-abi3-macosx_11_0_arm64.whl (31.1 MB)
# Requirement already satisfied: matplotlib in /Users/gedena/miniconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (2.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (3.19.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (3.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.14.1)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.42.0)
# Requirement already satisfied: packaging in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (23.0)
# Requirement already satisfied: setuptools in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (65.6.3)
# Requirement already satisfied: numpy>=1.20 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.24.2)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (1.6.3)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Using cached tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Collecting tensorboard<2.10,>=2.9
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.9) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-metal==0.5.0) (0.37.1)
# Collecting six>=1.12.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2.16.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-macos==2.9) (3.2.2)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/1t/sj3jytd91z53kgnkw3mqp59r0000gn/T/pip-install-d8ksgdsy/tensorflow-gpu_510ba77005bd44a0962bfa5f8597c582/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: python_version, keras, flatbuffers, tensorflow-gpu, tensorflow-estimator, six, opencv-python, tensorflow-metal, keras-preprocessing, tensorboard, tensorflow-macos
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.1.21
#     Uninstalling flatbuffers-23.1.21:
#       Successfully uninstalled flatbuffers-23.1.21
#   Running setup.py install for tensorflow-gpu ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for tensorflow-gpu did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/1t/sj3jytd91z53kgnkw3mqp59r0000gn/T/pip-install-d8ksgdsy/tensorflow-gpu_510ba77005bd44a0962bfa5f8597c582/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 1.4.0
# anaconda-clean          1.0
# anyio                   3.5.0
# appnope                 0.1.2
# argon2-cffi             21.3.0
# argon2-cffi-bindings    21.2.0
# asttokens               2.0.5
# astunparse              1.6.3
# attrs                   22.1.0
# Babel                   2.11.0
# backcall                0.2.0
# beautifulsoup4          4.11.1
# bleach                  4.1.0
# brotlipy                0.7.0
# cachetools              5.3.0
# certifi                 2022.12.7
# cffi                    1.15.1
# charset-normalizer      2.0.4
# comm                    0.1.2
# conda                   23.1.0
# conda-content-trust     0.1.3
# conda-package-handling  2.0.2
# conda_package_streaming 0.7.0
# contourpy               1.0.7
# cryptography            38.0.4
# cycler                  0.11.0
# debugpy                 1.5.1
# decorator               5.1.1
# defusedxml              0.7.1
# entrypoints             0.4
# executing               0.8.3
# fastjsonschema          2.16.2
# flatbuffers             1.12
# flit_core               3.6.0
# fonttools               4.38.0
# gast                    0.4.0
# google-auth             2.16.0
# google-auth-oauthlib    0.4.6
# google-pasta            0.2.0
# grpcio                  1.42.0
# h5py                    3.6.0
# idna                    3.4
# ipykernel               6.19.2
# ipython                 8.9.0
# ipython-genutils        0.2.0
# ipywidgets              7.6.5
# jedi                    0.18.1
# Jinja2                  3.1.2
# joblib                  1.2.0
# json5                   0.9.6
# jsonschema              4.16.0
# jupyter                 1.0.0
# jupyter_client          7.4.9
# jupyter-console         6.4.4
# jupyter_core            5.1.1
# jupyter-server          1.23.4
# jupyterlab              3.5.3
# jupyterlab-pygments     0.1.2
# jupyterlab_server       2.16.5
# jupyterlab-widgets      1.0.0
# keras                   2.9.0
# kiwisolver              1.4.4
# libclang                15.0.6.1
# lxml                    4.9.1
# Markdown                3.4.1
# MarkupSafe              2.1.2
# matplotlib              3.7.0
# matplotlib-inline       0.1.6
# mistune                 0.8.4
# nbclassic               0.4.8
# nbclient                0.5.13
# nbconvert               6.5.4
# nbformat                5.7.0
# nest-asyncio            1.5.6
# notebook                6.5.2
# notebook_shim           0.2.2
# numpy                   1.24.2
# oauthlib                3.2.2
# opt-einsum              3.3.0
# packaging               23.0
# pandas                  1.5.3
# pandocfilters           1.5.0
# parso                   0.8.3
# pexpect                 4.8.0
# pickleshare             0.7.5
# Pillow                  9.4.0
# pip                     22.3.1
# platformdirs            2.5.2
# plotly                  5.13.0
# pluggy                  1.0.0
# ply                     3.11
# prometheus-client       0.14.1
# prompt-toolkit          3.0.36
# protobuf                3.19.6
# psutil                  5.9.0
# ptyprocess              0.7.0
# pure-eval               0.2.2
# pyasn1                  0.4.8
# pyasn1-modules          0.2.8
# pycosat                 0.6.4
# pycparser               2.21
# Pygments                2.11.2
# pyOpenSSL               22.0.0
# pyparsing               3.0.9
# PyQt5-sip               12.11.0
# pyrsistent              0.18.0
# PySocks                 1.7.1
# python-dateutil         2.8.2
# python-version          0.0.2
# pytz                    2022.7.1
# pyzmq                   23.2.0
# qtconsole               5.4.0
# QtPy                    2.2.0
# requests                2.28.1
# requests-oauthlib       1.3.1
# rsa                     4.9
# ruamel.yaml             0.17.21
# ruamel.yaml.clib        0.2.6
# scikit-learn            1.2.1
# scipy                   1.10.0
# Send2Trash              1.8.0
# setuptools              65.6.3
# sip                     6.6.2
# six                     1.16.0
# sniffio                 1.2.0
# soupsieve               2.3.2.post1
# stack-data              0.2.0
# tenacity                8.2.1
# tensorboard             2.11.2
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.1
# tensorflow-estimator    2.11.0
# tensorflow-metal        0.7.1
# termcolor               2.2.0
# terminado               0.17.1
# threadpoolctl           3.1.0
# tinycss2                1.2.1
# toml                    0.10.2
# tomli                   2.0.1
# toolz                   0.12.0
# tornado                 6.2
# tqdm                    4.64.1
# traitlets               5.7.1
# typing_extensions       4.4.0
# urllib3                 1.26.14
# wcwidth                 0.2.5
# webencodings            0.5.1
# websocket-client        0.58.0
# Werkzeug                2.2.3
# wheel                   0.37.1
# widgetsnbextension      3.5.2
# wrapt                   1.14.1
# zstandard               0.18.0

# %%
# !pip install tensorflow-macos
# Out:
# Collecting tensorflow-macos
#   Using cached tensorflow_macos-2.11.0-cp310-cp310-macosx_12_0_arm64.whl (215.6 MB)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.6.3)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (3.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.42.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.24.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (2.11.2)
# Requirement already satisfied: setuptools in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (65.6.3)
# Requirement already satisfied: packaging in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (23.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (15.0.6.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (3.19.6)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.1.21-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (4.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-macos) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gedena/miniconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (3.2.2)
# Installing collected packages: flatbuffers, keras, tensorflow-macos
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
# Successfully installed flatbuffers-23.1.21 keras-2.11.0 tensorflow-macos-2.11.0

# %%
tensorflow list!
# Out:
#   Cell In[5], line 1
#     tensorflow list!
#                ^
# SyntaxError: invalid syntax

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 1.4.0
# anaconda-clean          1.0
# anyio                   3.5.0
# appnope                 0.1.2
# argon2-cffi             21.3.0
# argon2-cffi-bindings    21.2.0
# asttokens               2.0.5
# astunparse              1.6.3
# attrs                   22.1.0
# Babel                   2.11.0
# backcall                0.2.0
# beautifulsoup4          4.11.1
# bleach                  4.1.0
# brotlipy                0.7.0
# cachetools              5.3.0
# certifi                 2022.12.7
# cffi                    1.15.1
# charset-normalizer      2.0.4
# comm                    0.1.2
# conda                   23.1.0
# conda-content-trust     0.1.3
# conda-package-handling  2.0.2
# conda_package_streaming 0.7.0
# contourpy               1.0.7
# cryptography            38.0.4
# cycler                  0.11.0
# debugpy                 1.5.1
# decorator               5.1.1
# defusedxml              0.7.1
# entrypoints             0.4
# executing               0.8.3
# fastjsonschema          2.16.2
# flatbuffers             23.1.21
# flit_core               3.6.0
# fonttools               4.38.0
# gast                    0.4.0
# google-auth             2.16.0
# google-auth-oauthlib    0.4.6
# google-pasta            0.2.0
# grpcio                  1.42.0
# h5py                    3.6.0
# idna                    3.4
# ipykernel               6.19.2
# ipython                 8.9.0
# ipython-genutils        0.2.0
# ipywidgets              7.6.5
# jedi                    0.18.1
# Jinja2                  3.1.2
# joblib                  1.2.0
# json5                   0.9.6
# jsonschema              4.16.0
# jupyter                 1.0.0
# jupyter_client          7.4.9
# jupyter-console         6.4.4
# jupyter_core            5.1.1
# jupyter-server          1.23.4
# jupyterlab              3.5.3
# jupyterlab-pygments     0.1.2
# jupyterlab_server       2.16.5
# jupyterlab-widgets      1.0.0
# keras                   2.11.0
# kiwisolver              1.4.4
# libclang                15.0.6.1
# lxml                    4.9.1
# Markdown                3.4.1
# MarkupSafe              2.1.2
# matplotlib              3.7.0
# matplotlib-inline       0.1.6
# mistune                 0.8.4
# nbclassic               0.4.8
# nbclient                0.5.13
# nbconvert               6.5.4
# nbformat                5.7.0
# nest-asyncio            1.5.6
# notebook                6.5.2
# notebook_shim           0.2.2
# numpy                   1.24.2
# oauthlib                3.2.2
# opt-einsum              3.3.0
# packaging               23.0
# pandas                  1.5.3
# pandocfilters           1.5.0
# parso                   0.8.3
# pexpect                 4.8.0
# pickleshare             0.7.5
# Pillow                  9.4.0
# pip                     22.3.1
# platformdirs            2.5.2
# plotly                  5.13.0
# pluggy                  1.0.0
# ply                     3.11
# prometheus-client       0.14.1
# prompt-toolkit          3.0.36
# protobuf                3.19.6
# psutil                  5.9.0
# ptyprocess              0.7.0
# pure-eval               0.2.2
# pyasn1                  0.4.8
# pyasn1-modules          0.2.8
# pycosat                 0.6.4
# pycparser               2.21
# Pygments                2.11.2
# pyOpenSSL               22.0.0
# pyparsing               3.0.9
# PyQt5-sip               12.11.0
# pyrsistent              0.18.0
# PySocks                 1.7.1
# python-dateutil         2.8.2
# python-version          0.0.2
# pytz                    2022.7.1
# pyzmq                   23.2.0
# qtconsole               5.4.0
# QtPy                    2.2.0
# requests                2.28.1
# requests-oauthlib       1.3.1
# rsa                     4.9
# ruamel.yaml             0.17.21
# ruamel.yaml.clib        0.2.6
# scikit-learn            1.2.1
# scipy                   1.10.0
# Send2Trash              1.8.0
# setuptools              65.6.3
# sip                     6.6.2
# six                     1.16.0
# sniffio                 1.2.0
# soupsieve               2.3.2.post1
# stack-data              0.2.0
# tenacity                8.2.1
# tensorboard             2.11.2
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.1
# tensorflow-estimator    2.11.0
# tensorflow-macos        2.11.0
# tensorflow-metal        0.7.1
# termcolor               2.2.0
# terminado               0.17.1
# threadpoolctl           3.1.0
# tinycss2                1.2.1
# toml                    0.10.2
# tomli                   2.0.1
# toolz                   0.12.0
# tornado                 6.2
# tqdm                    4.64.1
# traitlets               5.7.1
# typing_extensions       4.4.0
# urllib3                 1.26.14
# wcwidth                 0.2.5
# webencodings            0.5.1
# websocket-client        0.58.0
# Werkzeug                2.2.3
# wheel                   0.37.1
# widgetsnbextension      3.5.2
# wrapt                   1.14.1
# zstandard               0.18.0

# %%
import tensorflow as tf
devices = tf.config.list_physical_devices()
print(devices)
tf.debugging.set_log_device_placement(True)
a=tf.random.normal([100,100])
b=tf.random.normal([100,100])
c = a*b
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Metal device set to: Apple M2
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.873980: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-14 15:34:23.874024: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-02-14 15:34:23.882212: I tensorflow/core/common_runtime/placer.cc:114] input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-02-14 15:34:23.882229: I tensorflow/core/common_runtime/placer.cc:114] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.882232: I tensorflow/core/common_runtime/placer.cc:114] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.885920: I tensorflow/core/common_runtime/placer.cc:114] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.885926: I tensorflow/core/common_runtime/placer.cc:114] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.885929: I tensorflow/core/common_runtime/placer.cc:114] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.889153: I tensorflow/core/common_runtime/placer.cc:114] shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-02-14 15:34:23.889158: I tensorflow/core/common_runtime/placer.cc:114] RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:23.889161: I tensorflow/core/common_runtime/placer.cc:114] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.244802: I tensorflow/core/common_runtime/placer.cc:114] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.244811: I tensorflow/core/common_runtime/placer.cc:114] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.244814: I tensorflow/core/common_runtime/placer.cc:114] Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.244816: I tensorflow/core/common_runtime/placer.cc:114] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.250484: I tensorflow/core/common_runtime/placer.cc:114] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.250490: I tensorflow/core/common_runtime/placer.cc:114] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.250493: I tensorflow/core/common_runtime/placer.cc:114] AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-02-14 15:34:24.250495: I tensorflow/core/common_runtime/placer.cc:114] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0

# %%
import os

# %%
os.path.join('data','happy')
# Out:
# 'data/happy'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 3
#       1 gpus = tf.config.experimental.list_physical_devices('GPU')
#       2 for gpu in gpus:
# ----> 3     tf.config.experimental.set_memory_growth(gpu, True)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/framework/config.py:716, in set_memory_growth(device, enable)
#     691 @tf_export('config.experimental.set_memory_growth')
#     692 def set_memory_growth(device, enable):
#     693   """Set if memory growth should be enabled for a `PhysicalDevice`.
#     694
#     695   If memory growth is enabled for a `PhysicalDevice`, the runtime initialization
#    (...)
#     714     RuntimeError: Runtime is already initialized.
#     715   """
# --> 716   context.context().set_memory_growth(device, enable)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1643, in Context.set_memory_growth(self, dev, enable)
#    1640   return
#    1642 if self._context_handle is not None:
# -> 1643   raise RuntimeError(
#    1644       "Physical devices cannot be modified after being initialized")
#    1646 self._memory_growth_map[dev] = enable
#
# RuntimeError: Physical devices cannot be modified after being initialized
